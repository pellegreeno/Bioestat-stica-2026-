# %% [markdown]
# <a href="https://colab.research.google.com/github/pellegreeno/Bioestat-stica-2026-/blob/main/semana02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação de bibliotecas

# %%
#maneira simples de se referir as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Explicação das Variáveis
#
# O DataFrame `dados` contém as seguintes variáveis:
#
# *   **`ambiente`**: Representa o tipo de ambiente onde a coleta foi realizada (mata, cerrado, campo). É uma variável **qualitativa nominal**, pois as categorias não possuem uma ordem natural.
#
# *   **`nivel_impacto`**: Indica o nível de impacto ambiental observado (baixo, moderado, alto). É uma variável **qualitativa ordinal**, pois as categorias possuem uma ordem intrínseca.
#
# *   **`riqueza_especies`**: O número de diferentes espécies encontradas na parcela. É uma variável **quantitativa discreta**, pois resulta de uma contagem e assume valores inteiros.
#
# *   **`cobertura_vegetal_pct`**: A porcentagem de cobertura vegetal do solo na parcela. É uma variável **quantitativa contínua**, pois pode assumir qualquer valor dentro de um intervalo (de 0 a 100).

# %% [markdown]
# # Conjunto de dados biológicos

# %%
dados = pd.DataFrame({
    "ambiente": [
        "mata", "cerrado", "campo", "mata", "cerrado",
        "campo", "mata", "cerrado", "mata", "campo",
        "cerrado", "mata", "campo", "cerrado", "mata",
        "campo", "cerrado", "mata", "campo", "cerrado"
    ],  # nominal
    "nivel_impacto": [
        "baixo", "moderado", "alto", "baixo", "moderado",
        "alto", "baixo", "moderado", "baixo", "alto",
        "moderado", "baixo", "alto", "moderado", "baixo",
        "alto", "moderado", "baixo", "alto", "moderado"
    ],  # ordinal
    "riqueza_especies": [
        18, 12, 7, 20, 14, 6, 22, 13, 19, 8,
        15, 21, 5, 11, 23, 7, 14, 20, 6, 12
    ],  # discreta
    "cobertura_vegetal_pct": [
        88.5, 64.2, 31.8, 91.0, 68.7, 28.4, 94.3, 61.5, 86.9, 35.2,
        70.1, 92.4, 24.8, 58.9, 96.0, 32.7, 66.3, 89.7, 27.5, 63.8
    ]  # contínua
})

dados.head()
# Out:
#    id ambiente nivel_impacto  riqueza_especies  cobertura_vegetal_pct
# 0   1     mata         baixo                18                   88.5
# 1   2  cerrado      moderado                12                   64.2
# 2   3    campo          alto                 7                   31.8
# 3   4     mata         baixo                20                   91.0
# 4   5  cerrado      moderado                14                   68.7

# %% [markdown]
# # Tabelas de frequências

# %%
# 3. Frequência absoluta da variável nominal: ambiente
freq_ambiente = dados["ambiente"].value_counts()
freq_ambiente
# Out:
# ambiente
# mata       7
# cerrado    7
# campo      6
# Name: count, dtype: int64

# %%
# 4. Frequência relativa (%) da variável nominal: ambiente
freq_ambiente_rel = dados["ambiente"].value_counts(normalize=True) * 100
freq_ambiente_rel.round(1)
# Out:
# ambiente
# mata       35.0
# cerrado    35.0
# campo      30.0
# Name: proportion, dtype: float64

# %%
# 5. Frequência da variável ordinal: nível de impacto
freq_impacto = dados["nivel_impacto"].value_counts()
freq_impacto
# Out:
# nivel_impacto
# baixo       7
# moderado    7
# alto        6
# Name: count, dtype: int64

# %%
# 6. Frequência da variável discreta: riqueza de espécies
freq_riqueza = dados["riqueza_especies"].value_counts().sort_index()
freq_riqueza
# Out:
# riqueza_especies
# 5     1
# 6     2
# 7     2
# 8     1
# 11    1
# 12    2
# 13    1
# 14    2
# 15    1
# 18    1
# 19    1
# 20    2
# 21    1
# 22    1
# 23    1
# Name: count, dtype: int64

# %%
# 7. Classes para a variável contínua: cobertura vegetal
print("Exemplo de classes com intervalo fechado à esquerda:")

classes_cobertura = pd.cut(
    dados["cobertura_vegetal_pct"],
    bins=[20, 40, 60, 80, 101],
    labels=["[20-40)", "[40-60)", "[60-80)", "[80-101)"],
    right=False
)

freq_cobertura = classes_cobertura.value_counts().sort_index()
freq_cobertura
# Out:
# Exemplo de classes com intervalo fechado à esquerda:
# cobertura_vegetal_pct
# [20-40)     6
# [40-60)     1
# [60-80)     6
# [80-101)    7
# Name: count, dtype: int64

# %% [markdown]
# # Gráficos

# %% [markdown]
# ## Gráfico de barras

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=dados, x="ambiente")
plt.title("Número de parcelas por ambiente")
plt.xlabel("Ambiente")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# ## Gráfico de pizza ou setores

# %%
freq_ambiente = dados["ambiente"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(
    freq_ambiente,
    labels=freq_ambiente.index,
    autopct="%.1f%%"
)
plt.title("Distribuição das parcelas por ambiente (%)")
plt.show()

# %% [markdown]
# ## Histograma

# %%
plt.figure(figsize=(6, 4))
sns.histplot(
    data=dados,
    x="cobertura_vegetal_pct",
    bins=[20, 40, 60, 80, 101],
    kde=False
)
plt.title("Distribuição da cobertura vegetal nas parcelas")
plt.xlabel("Cobertura vegetal (%)")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# ## Boxplot ou gráfico de caixas-e-bigodes

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=dados, x="cobertura_vegetal_pct")
plt.title("Boxplot da cobertura vegetal")
plt.xlabel("Cobertura vegetal (%)")
plt.show()

# %% [markdown]
# ## Gráfico de dispersão

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(
    data=dados,
    x="cobertura_vegetal_pct",
    y="riqueza_especies",
    hue="ambiente"
)
plt.title("Riqueza de espécies vs. cobertura vegetal")
plt.xlabel("Cobertura vegetal (%)")
plt.ylabel("Riqueza de espécies")
plt.show()

# %% [markdown]
# ## Gráfico de dispersão interativo com Plotly

# %%
fig = px.scatter(
    dados,
    x="cobertura_vegetal_pct",
    y="riqueza_especies",
    color="ambiente",
    title="Riqueza de espécies vs. cobertura vegetal (interativo)"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="39514b3f-a46c-4991-b023-80f3103a7509" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39514b3f-a46c-4991-b023-80f3103a7509")) {                    Plotly.newPlot(                        "39514b3f-a46c-4991-b023-80f3103a7509",                        [{"hovertemplate":"ambiente=mata\u003cbr\u003ecobertura_vegetal_pct=%{x}\u003cbr\u003eriqueza_especies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mata","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"mata","orientation":"v","showlegend":true,"x":[88.5,91.0,94.3,86.9,92.4,96.0,89.7],"xaxis":"x","y":[18,20,22,19,21,23,20],"yaxis":"y","type":"scatter"},{"hovertemplate":"ambiente=cerrado\u003cbr\u003ecobertura_vegetal_pct=%{x}\u003cbr\u003eriqueza_especies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"cerrado","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"cerrado","orientation":"v","showlegend":true,"x":[64.2,68.7,61.5,70.1,58.9,66.3,63.8],"xaxis":"x","y":[12,14,13,15,11,14,12],"yaxis":"y","type":"scatter"},{"hovertemplate":"ambiente=campo\u003cbr\u003ecobertura_vegetal_pct=%{x}\u003cbr\u003eriqueza_especies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"campo","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"campo","orientation":"v","showlegend":true,"x":[31.8,28.4,35.2,24.8,32.7,27.5],"xaxis":"x","y":[7,6,8,5,7,6],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...
